# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('data/apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
print(f'shape: {df_apps.shape}')
# Out:
# shape: (10841, 12)

# %%
df_apps.sample(5)
# Out:
#                                   App       Category  Rating  Reviews  \
# 10328    imo beta free calls and text  COMMUNICATION    4.30   659395
# 10114                   Mobile Strike         FAMILY    3.90   903392
# 5967   MSN Sports - Scores & Schedule         SPORTS    4.50    35394
# 6960   Dragonplay™ Poker Texas Holdem           GAME    4.50   197979
# 1915                            FE IP          TOOLS     NaN        3
#
#        Size_MBs     Installs  Type Price Content_Rating         Genres  \
# 10328     11.00  100,000,000  Free     0       Everyone  Communication
# 10114     19.00   50,000,000  Free     0   Everyone 10+       Strategy
# 5967      21.00      500,000  Free     0       Everyone         Sports
# 6960      36.00    1,000,000  Free     0           Teen           Card
# 1915      12.00        1,000  Free     0       Everyone          Tools
#
#            Last_Updated         Android_Ver
# 10328      June 7, 2018          4.0 and up
# 10114     June 14, 2018          4.1 and up
# 5967       July 5, 2018          4.2 and up
# 6960     August 7, 2018  Varies with device
# 1915   October 27, 2017          3.0 and up

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(columns=['Last_Updated', 'Android_Ver'], axis=1, inplace=True)

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
print(f'NaN values: {df_apps["Rating"].isna().values.sum()}')
# Out:
# NaN values: 1474

# %%
df_apps_clean = df_apps.dropna()
df_apps_clean.shape
# Out:
# (9367, 10)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]
print(duplicated_rows.shape)
duplicated_rows.head()
# Out:
# (476, 10)
#                                              App Category  Rating  Reviews  \
# 946                       420 BZ Budeze Delivery  MEDICAL    5.00        2
# 1133                                 MouseMingle   DATING    2.70        3
# 1196  Cardiac diagnosis (heart rate, arrhythmia)  MEDICAL    4.40        8
# 1231                                Sway Medical  MEDICAL    5.00        3
# 1247              Chat Kids - Chat Room For Kids   DATING    4.70        6
#
#       Size_MBs Installs  Type   Price Content_Rating   Genres
# 946      11.00      100  Free       0     Mature 17+  Medical
# 1133      3.90      100  Free       0     Mature 17+   Dating
# 1196      6.50      100  Paid  $12.99       Everyone  Medical
# 1231     22.00      100  Free       0       Everyone  Medical
# 1247      4.90      100  Free       0     Mature 17+   Dating

# %%
df_apps_clean[df_apps_clean.App =='Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10809     0           Teen  Social
# 10810     0           Teen  Social

# %%
# with out the use of subset it will use all columns
df_apps_clean = df_apps_clean.drop_duplicates()
df_apps_clean[df_apps_clean.App=='Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10810     0           Teen  Social

# %%
df_apps_clean = df_apps_clean.drop_duplicates(subset=['App', 'Type', 'Price'])
df_apps_clean[df_apps_clean.App=='Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social

# %%
df_apps_clean.shape
# Out:
# (8199, 10)

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean.sort_values('Rating', ascending=False).head()
# Out:
#                       App     Category  Rating  Reviews  Size_MBs Installs  \
# 21    KBA-EZ Health Guide      MEDICAL    5.00        4     25.00        1
# 1230         Sway Medical      MEDICAL    5.00        3     22.00      100
# 1227    AJ Men's Grooming    LIFESTYLE    5.00        2     22.00      100
# 1224       FK Dedinje BGD       SPORTS    5.00       36      2.60      100
# 1223      CB VIDEO VISION  PHOTOGRAPHY    5.00       13      2.60      100
#
#       Type Price Content_Rating       Genres
# 21    Free     0       Everyone      Medical
# 1230  Free     0       Everyone      Medical
# 1227  Free     0       Everyone    Lifestyle
# 1224  Free     0       Everyone       Sports
# 1223  Free     0       Everyone  Photography

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean.sort_values('Size_MBs', ascending=False).head()
# Out:
#                                   App            Category  Rating  Reviews  \
# 9942   Talking Babsy Baby: Baby Games           LIFESTYLE    4.00   140995
# 10687          Hungry Shark Evolution                GAME    4.50  6074334
# 9943            Miami crime simulator                GAME    4.00   254518
# 9944     Gangster Town: Vice District              FAMILY    4.30    65146
# 3144                       Vi Trainer  HEALTH_AND_FITNESS    3.60      124
#
#        Size_MBs     Installs  Type Price Content_Rating  \
# 9942     100.00   10,000,000  Free     0       Everyone
# 10687    100.00  100,000,000  Free     0           Teen
# 9943     100.00   10,000,000  Free     0     Mature 17+
# 9944     100.00   10,000,000  Free     0     Mature 17+
# 3144     100.00        5,000  Free     0       Everyone
#
#                        Genres
# 9942   Lifestyle;Pretend Play
# 10687                  Arcade
# 9943                   Action
# 9944               Simulation
# 3144         Health & Fitness

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values('Reviews', ascending=False).head()
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL    4.10
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10806                                 Instagram         SOCIAL    4.50
# 10784  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10650                            Clash of Clans           GAME    4.60
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10806  66577313      5.30  1,000,000,000  Free     0           Teen
# 10784  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10650  44891723     98.00    100,000,000  Free     0   Everyone 10+
#
#               Genres
# 10805         Social
# 10785  Communication
# 10806         Social
# 10784  Communication
# 10650       Strategy

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_clean.Content_Rating.value_counts()

# %%
ratings
# Out:
# Content_Rating
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
fig = px.pie(labels=ratings.index, values=ratings.values)
fig.show()

# %%
fig = px.pie(
    labels=ratings.index,
    values=ratings.values,
    title='Content Rating',
    names=ratings.index
    )
fig.show()

# %%
fig = px.pie(
    labels=ratings.index,
    values=ratings.values,
    title='Content Rating',
    names=ratings.index,
    hole=0.6
    )
fig.show()

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_clean.Installs.describe()
# Out:
# count          8199
# unique           19
# top       1,000,000
# freq           1417
# Name: Installs, dtype: object

# %%
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8199 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   object
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   object
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 704.6+ KB

# %%
df_apps_clean.Installs = df_apps_clean.Installs.astype(str).str.replace(',', '')
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)

# %%
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean.Price = df_apps_clean.Price.astype(str).str.replace('$', '')
df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price)

# %%
df_apps_clean.sort_values('Price', ascending=False).head(25)
# Out:
#                                                     App   Category  Rating  \
# 3946                           I'm Rich - Trump Edition  LIFESTYLE    3.60
# 2461                                 I AM RICH PRO PLUS    FINANCE    4.00
# 4606                                  I Am Rich Premium    FINANCE    4.10
# 3145                                 I am rich(premium)    FINANCE    3.50
# 3554                                         💎 I'm rich  LIFESTYLE    3.80
# 5765                                          I am rich  LIFESTYLE    3.80
# 1946                     I am rich (Most expensive app)    FINANCE    4.10
# 2775                                      I Am Rich Pro     FAMILY    4.40
# 3221                                     I am Rich Plus     FAMILY    4.00
# 3114                                          I am Rich    FINANCE    4.30
# 1331                             most expensive app (H)     FAMILY    4.30
# 2394                                         I am Rich!    FINANCE    3.80
# 3897                                          I Am Rich     FAMILY    3.60
# 2193                                I am extremely Rich  LIFESTYLE    2.90
# 3856                                      I am rich VIP  LIFESTYLE    3.80
# 2281                          Vargo Anesthesia Mega App    MEDICAL    4.60
# 1407                                       LTC AS Legal    MEDICAL    4.00
# 2629                                   I am Rich Person  LIFESTYLE    4.20
# 2481                            A Manual of Acupuncture    MEDICAL    3.50
# 4264                            Golfshot Plus: Golf GPS     SPORTS    4.10
# 504                           AP Art History Flashcards     FAMILY    5.00
# 2207                                           EMT PASS    MEDICAL    3.40
# 2463                                 PTA Content Master    MEDICAL    4.20
# 3241  Muscle Premium - Human Anatomy, Kinesiology, B...    MEDICAL    4.20
# 4772   Human Anatomy Atlas 2018: Complete 3D Human Body    MEDICAL    4.50
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating         Genres
# 3946      275      7.30     10000  Paid 400.00       Everyone      Lifestyle
# 2461       36     41.00      1000  Paid 399.99       Everyone        Finance
# 4606     1867      4.70     50000  Paid 399.99       Everyone        Finance
# 3145      472      0.94      5000  Paid 399.99       Everyone        Finance
# 3554      718     26.00     10000  Paid 399.99       Everyone      Lifestyle
# 5765     3547      1.80    100000  Paid 399.99       Everyone      Lifestyle
# 1946      129      2.70      1000  Paid 399.99           Teen        Finance
# 2775      201      2.70      5000  Paid 399.99       Everyone  Entertainment
# 3221      856      8.70     10000  Paid 399.99       Everyone  Entertainment
# 3114      180      3.80      5000  Paid 399.99       Everyone        Finance
# 1331        6      1.50       100  Paid 399.99       Everyone  Entertainment
# 2394       93     22.00      1000  Paid 399.99       Everyone        Finance
# 3897      217      4.90     10000  Paid 389.99       Everyone  Entertainment
# 2193       41      2.90      1000  Paid 379.99       Everyone      Lifestyle
# 3856      411      2.60     10000  Paid 299.99       Everyone      Lifestyle
# 2281       92     32.00      1000  Paid  79.99       Everyone        Medical
# 1407        6      1.30       100  Paid  39.99       Everyone        Medical
# 2629      134      1.80      1000  Paid  37.99       Everyone      Lifestyle
# 2481      214     68.00      1000  Paid  33.99       Everyone        Medical
# 4264     3387     25.00     50000  Paid  29.99       Everyone         Sports
# 504         1     96.00        10  Paid  29.99     Mature 17+      Education
# 2207       51      2.40      1000  Paid  29.99       Everyone        Medical
# 2463       64     41.00      1000  Paid  29.99       Everyone        Medical
# 3241      168     25.00     10000  Paid  24.99       Everyone        Medical
# 4772     2921     25.00    100000  Paid  24.99       Everyone        Medical

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_apps_clean.Price = df_apps_clean.Price[df_apps_clean.Price < 250]

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean.sort_values('Price' ,ascending=False).head(25)
# Out:
#                                                     App     Category  Rating  \
# 2281                          Vargo Anesthesia Mega App      MEDICAL    4.60
# 1407                                       LTC AS Legal      MEDICAL    4.00
# 2629                                   I am Rich Person    LIFESTYLE    4.20
# 2481                            A Manual of Acupuncture      MEDICAL    3.50
# 2463                                 PTA Content Master      MEDICAL    4.20
# 2207                                           EMT PASS      MEDICAL    3.40
# 4264                            Golfshot Plus: Golf GPS       SPORTS    4.10
# 504                           AP Art History Flashcards       FAMILY    5.00
# 4772   Human Anatomy Atlas 2018: Complete 3D Human Body      MEDICAL    4.50
# 3241  Muscle Premium - Human Anatomy, Kinesiology, B...      MEDICAL    4.20
# 2119                                         NewTek NDI  PHOTOGRAPHY    3.50
# 4470                                  DRAGON QUEST VIII       FAMILY    4.50
# 2293                               Hospitalist Handbook      MEDICAL    4.80
# 526                          USMLE Step 2 CK Flashcards       FAMILY    5.00
# 2473                            boattheory.ch Full 2018       FAMILY    4.70
# 4090                             I am Rich Premium Plus      FINANCE    4.60
# 1508                                 SkyTest BU/GU Lite     BUSINESS    2.90
# 3778                            The World Ends With You         GAME    4.60
# 2603                         2017 EMRA Antibiotic Guide      MEDICAL    4.40
# 3439                            Trine 2: Complete Story         GAME    3.80
# 1795                               Navi Radiography Pro      MEDICAL    4.70
# 2048                     Interactive CT and MRI Anatomy      MEDICAL    3.40
# 2697                         Electrician Calculator Pro        TOOLS    3.90
# 3701                                    DRAGON QUEST IV       FAMILY    4.70
# 3375                                     DRAGON QUEST V       FAMILY    4.70
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating        Genres
# 2281       92     32.00      1000  Paid  79.99       Everyone       Medical
# 1407        6      1.30       100  Paid  39.99       Everyone       Medical
# 2629      134      1.80      1000  Paid  37.99       Everyone     Lifestyle
# 2481      214     68.00      1000  Paid  33.99       Everyone       Medical
# 2463       64     41.00      1000  Paid  29.99       Everyone       Medical
# 2207       51      2.40      1000  Paid  29.99       Everyone       Medical
# 4264     3387     25.00     50000  Paid  29.99       Everyone        Sports
# 504         1     96.00        10  Paid  29.99     Mature 17+     Education
# 4772     2921     25.00    100000  Paid  24.99       Everyone       Medical
# 3241      168     25.00     10000  Paid  24.99       Everyone       Medical
# 2119       77      1.20      1000  Paid  19.99       Everyone   Photography
# 4470     7812     27.00     50000  Paid  19.99   Everyone 10+  Role Playing
# 2293       12     18.00      1000  Paid  19.99       Everyone       Medical
# 526         1     40.00        10  Paid  19.99       Everyone     Education
# 2473       54     50.00      1000  Paid  19.40       Everyone     Education
# 4090      459      2.00     10000  Paid  18.99       Everyone       Finance
# 1508       28     20.00       500  Paid  17.99       Everyone      Business
# 3778     4108     13.00     10000  Paid  17.99   Everyone 10+        Arcade
# 2603       12      3.80      1000  Paid  16.99       Everyone       Medical
# 3439      252     11.00     10000  Paid  16.99           Teen        Action
# 1795       11    100.00       500  Paid  15.99       Everyone       Medical
# 2048       35     24.00      1000  Paid  15.46       Everyone       Medical
# 2697       47      0.26      1000  Paid  14.99       Everyone         Tools
# 3701     1647     16.00     10000  Paid  14.99       Everyone  Role Playing
# 3375     1667     17.00     10000  Paid  14.99           Teen  Role Playing

# %%
df_apps_clean.dropna(inplace=True) # clear NaN in price > 250 apps
df_apps_clean['Revenue_Estimate'] = df_apps_clean.Installs.multiply(df_apps_clean.Price)
df_apps_clean.sort_values('Revenue_Estimate', ascending=False).head(25)
# Out:
#                                                    App         Category  \
# 9220                                         Minecraft           FAMILY
# 8825                                     Hitman Sniper             GAME
# 7151                     Grand Theft Auto: San Andreas             GAME
# 7477                               Facetune - For Free      PHOTOGRAPHY
# 7977                           Sleep as Android Unlock        LIFESTYLE
# 6594                               DraStic DS Emulator             GAME
# 6082                                      Weather Live          WEATHER
# 7954                                       Bloons TD 5           FAMILY
# 7633                           Five Nights at Freddy's             GAME
# 6746                        Card Wars - Adventure Time           FAMILY
# 6856                                           Threema    COMMUNICATION
# 7044                                            Tasker            TOOLS
# 4772  Human Anatomy Atlas 2018: Complete 3D Human Body          MEDICAL
# 6406                             NBA JAM by EA SPORTS™           FAMILY
# 6496                             Beautiful Widgets Pro  PERSONALIZATION
# 6023                                   Toca Life: City        EDUCATION
# 7563                                        True Skate           SPORTS
# 7988                                 Where's My Water?           FAMILY
# 4264                           Golfshot Plus: Golf GPS           SPORTS
# 4912                                   DRAGON QUEST VI           FAMILY
# 6221                      ES File Explorer/Manager PRO     PRODUCTIVITY
# 6388                         Five Nights at Freddy's 2           FAMILY
# 6139                         Cameringo+ Filters Camera      PHOTOGRAPHY
# 5908                              Farming Simulator 16           FAMILY
# 5389                          FINAL FANTASY DIMENSIONS           FAMILY
#
#       Rating  Reviews  Size_MBs  Installs  Type  Price Content_Rating  \
# 9220    4.50  2376564     19.00  10000000  Paid   6.99   Everyone 10+
# 8825    4.60   408292     29.00  10000000  Paid   0.99     Mature 17+
# 7151    4.40   348962     26.00   1000000  Paid   6.99     Mature 17+
# 7477    4.40    49553     48.00   1000000  Paid   5.99       Everyone
# 7977    4.50    23966      0.85   1000000  Paid   5.99       Everyone
# 6594    4.60    87766     12.00   1000000  Paid   4.99       Everyone
# 6082    4.50    76593      4.75    500000  Paid   5.99       Everyone
# 7954    4.60   190086     94.00   1000000  Paid   2.99       Everyone
# 7633    4.60   100805     50.00   1000000  Paid   2.99           Teen
# 6746    4.30   129603     23.00   1000000  Paid   2.99   Everyone 10+
# 6856    4.50    51110      3.50   1000000  Paid   2.99       Everyone
# 7044    4.60    43045      3.40   1000000  Paid   2.99       Everyone
# 4772    4.50     2921     25.00    100000  Paid  24.99       Everyone
# 6406    4.30    56444     43.00    500000  Paid   4.99       Everyone
# 6496    4.20    97890     14.00   1000000  Paid   2.49       Everyone
# 6023    4.70    31085     24.00    500000  Paid   3.99       Everyone
# 7563    4.40   129409     73.00   1000000  Paid   1.99       Everyone
# 7988    4.70   188740     69.00   1000000  Paid   1.99       Everyone
# 4264    4.10     3387     25.00     50000  Paid  29.99       Everyone
# 4912    4.40     3358     17.00    100000  Paid  14.99       Everyone
# 6221    4.70    81614      6.60    500000  Paid   2.99       Everyone
# 6388    4.60    73919     40.00    500000  Paid   2.99           Teen
# 6139    4.60    28107      5.70    500000  Paid   2.99       Everyone
# 5908    4.20    32812     14.00    500000  Paid   2.99       Everyone
# 5389    4.30     8450      1.10    100000  Paid  13.99       Everyone
#
#                          Genres  Revenue_Estimate
# 9220  Arcade;Action & Adventure     69,900,000.00
# 8825                     Action      9,900,000.00
# 7151                     Action      6,990,000.00
# 7477                Photography      5,990,000.00
# 7977                  Lifestyle      5,990,000.00
# 6594                     Action      4,990,000.00
# 6082                    Weather      2,995,000.00
# 7954                   Strategy      2,990,000.00
# 7633                     Action      2,990,000.00
# 6746    Card;Action & Adventure      2,990,000.00
# 6856              Communication      2,990,000.00
# 7044                      Tools      2,990,000.00
# 4772                    Medical      2,499,000.00
# 6406  Sports;Action & Adventure      2,495,000.00
# 6496            Personalization      2,490,000.00
# 6023     Education;Pretend Play      1,995,000.00
# 7563                     Sports      1,990,000.00
# 7988         Puzzle;Brain Games      1,990,000.00
# 4264                     Sports      1,499,500.00
# 4912               Role Playing      1,499,000.00
# 6221               Productivity      1,495,000.00
# 6388                   Strategy      1,495,000.00
# 6139                Photography      1,495,000.00
# 5908       Simulation;Education      1,495,000.00
# 5389               Role Playing      1,399,000.00

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
top10_category = df_apps_clean.Category.value_counts()[:10]
top10_category
# Out:
# Category
# FAMILY             1606
# GAME                910
# TOOLS               719
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: count, dtype: int64

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
bar = px.bar(x=top10_category.index,
             y=top10_category.values,
             labels=top10_category.name,
             title='Top 10 Category'
             )

bar.update_layout(xaxis_title='Category Name', yaxis_title='Number Of Apps')

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
category_installs = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum})

# %%
category_installs.sort_values(by='Installs', ascending=True, inplace=True)
h_bar = px.bar(
    x=category_installs.Installs,
    y=category_installs.index,
    orientation='h',
    title='Installation Numbers per Category',
)
h_bar.update_layout(xaxis_title='Number Of Downloads', yaxis_title='Category')
h_bar.show()

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
df_apps_in_category = df_apps_clean.groupby('Category').agg({'App': pd.Series.count})
df_apps_num_install = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum})
df_apps_combined = pd.merge(left=df_apps_in_category, right=df_apps_num_install, on='Category')
df_apps_combined.sort_values('Installs', inplace=True, ascending=False)
scatter = px.scatter(df_apps_combined,
    x='App',
    y='Installs',
    hover_name=df_apps_combined.index,
    title='Category Concentration',
    size='App',
    color='Installs'  
)
scatter.update_layout(
    xaxis_title='Number of Apps (Lower=More Concentrated)',
    yaxis_title='Installation',
    yaxis=dict(type='log')
)

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
print(len(df_apps_clean.Genres.unique()))
df_apps_clean.Genres.value_counts().sort_values()[:5]
stack = df_apps_clean.Genres.str.split(';', expand=True).stack()
print(f'We now have a single column with shape: {stack.shape}')
num_genres = stack.value_counts()
print(f'Number of genres: {len(num_genres)}')
# Out:
# 114
# We now have a single column with shape: (8564,)
# Number of genres: 53

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
bar = px.bar(
    x=num_genres.index[:20],
    y=num_genres.values[:20],
    title='Top Genres',
    hover_name=num_genres.index[:20],
    color=num_genres.values[:20],
    color_continuous_scale='Agsunset'
)
bar.update_layout(
    xaxis_title='Genre',
    yaxis_title='Number of Apps',
    coloraxis_showscale=False   
)

bar.show()

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.
